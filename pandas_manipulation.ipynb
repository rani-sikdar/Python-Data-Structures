# %% [markdown]
# <a href="https://colab.research.google.com/github/rani-sikdar/Python-Data-Structures/blob/main/pandas_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
list_ = [1,2,3,4,5,5]
series1= pd.Series(list_)
print(list_)
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
data = np.array(['a','b','c','e'])
print(pd.Series(data))
# Out:
# 0    a
# 1    b
# 2    c
# 3    e
# dtype: object

# %%
data = np.array(['a','b','c','e'])
print(pd.Series(data, index=[10,11,12,13]))
# Out:
# 10    a
# 11    b
# 12    c
# 13    e
# dtype: object

# %%
dict1 = {'Name': 'Rani', 'age':25, 'Salary':75000}
print(pd.Series(dict1))
# Out:
# Name       Rani
# age          25
# Salary    75000
# dtype: object

# %%
print(pd.Series(10, index=[0,1,2,3,4,5]))
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# 5    10
# dtype: int64

# %%
series1 = pd.Series(np.linspace(3,33,3))
print(series1)
# Out:
# 0     3.0
# 1    18.0
# 2    33.0
# dtype: float64

# %%
series2 = pd.Series(np.random.randn(3))
print(series2)
# Out:
# 0    0.444019
# 1   -0.342717
# 2   -0.071255
# dtype: float64

# %%
print(pd.Series(range(5)))
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
series3 = pd.Series(range(1, 20, 3), index=[x for x in 'abcdefg'])
print(series3)
# Out:
# a     1
# b     4
# c     7
# d    10
# e    13
# f    16
# g    19
# dtype: int64

# %%
lst = ['rani', 'is', 'growing.']
print(pd.DataFrame(lst))
# Out:
#           0
# 0      rani
# 1        is
# 2  growing.

# %%
xx= pd.DataFrame(lst)
xx
# Out:
#           0
# 0      rani
# 1        is
# 2  growing.

# %%
list2 = [[1, 'Geeks'], [2, 'For'], [3, 'Geeks']]

print(pd.DataFrame(list2, columns=['Id', 'Data']))
# Out:
#    Id   Data
# 0   1  Geeks
# 1   2    For
# 2   3  Geeks

# %%
data = {'Name': ['Tom', 'Dick', 'Harry'], 'Age':[22, 25, 28]}

print(pd.DataFrame(data))

df= pd.DataFrame(data)
df
# Out:
#     Name  Age
# 0    Tom   22
# 1   Dick   25
# 2  Harry   28
#     Name  Age
# 0    Tom   22
# 1   Dick   25
# 2  Harry   28

# %%
df.head(2)
# Out:
#    Name  Age
# 0   Tom   22
# 1  Dick   25

# %%
df.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %%
df = df.drop(['Name'], axis=1)

# %%
df
# Out:
#    Age
# 0   22
# 1   25
# 2   28

# %%
df.corr()
# Out:
#      Age
# Age  1.0

# %%
df.values
# Out:
# array([[22],
#        [25],
#        [28]])

# %%
df.interpolate()
# Out:
#    Age
# 0   22
# 1   25
# 2   28

# %%
import pandas as pd

  # Convert a string to a datetime object
date_string = '2024-07-17'
dt = pd.to_datetime(date_string)
print(dt)
# Out:
# 2024-07-17 00:00:00

# %%
from datetime import datetime
date_string = '2024-07-12'
dt = datetime.strptime(date_string, '%Y-%m-%d')
print(dt)
# Out:
# 2024-07-12 00:00:00

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   25.0
# std     3.0
# min    22.0
# 25%    23.5
# 50%    25.0
# 75%    26.5
# max    28.0

# %%
bp = df.boxplot(column= 'Age', grid=False)
bp
# Out:
# <Axes: >

# %%
pt = df['Age'].plot.hist()

# %%
df.sort_values(by='Age', ascending=True)
# Out:
#    Age
# 0   22
# 1   25
# 2   28

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
df.groupby(by= ['Age']).mean()
# Out:
# Empty DataFrame
# Columns: []
# Index: [22, 25, 28]

# %%
df.all()
# Out:
# Age    True
# dtype: bool
