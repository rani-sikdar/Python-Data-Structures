# %% [markdown]
# <a href="https://colab.research.google.com/github/rani-sikdar/Python-Data-Structures/blob/main/Pandas_data_analysis_coding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd_
df_ = pd_.Series()

# %%
df= pd.Series()

# %%
data = np.array(['p', 'y', 't', 'h', 'o','n'])

# convert array to Series
print(pd.Series(data))
# Out:
# 0    p
# 1    y
# 2    t
# 3    h
# 4    o
# 5    n
# dtype: object

# %%
data = np.array(['p', 'y', 't', 'h', 'o','n'])

# convert array to Series
print(pd.Series(data, index=[11,12,13,14,15,16]))
# Out:
# 11    p
# 12    y
# 13    t
# 14    h
# 15    o
# 16    n
# dtype: object

# %%
list_ = ['p', 'y', 't', 'h', 'o','n']
print(pd.Series(list_))
# Out:
# 0    p
# 1    y
# 2    t
# 3    h
# 4    o
# 5    n
# dtype: object

# %%
dict_ = {'Python': 10,
  'is': 20,
  'fun.': 30}
print(pd.Series(dict_))
# Out:
# Python    10
# is        20
# fun.      30
# dtype: int64

# %%
series_ = pd.Series(100, index=[11,12,13,14,15])
series_
# Out:
# 11    100
# 12    100
# 13    100
# 14    100
# 15    100
# dtype: int64

# %%
print(pd.Series(range(5)))
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
ser = pd.Series(range(1, 20, 3),
index=[x for x in 'abcdefg'])
print(ser)
# Out:
# a     1
# b     4
# c     7
# d    10
# e    13
# f    16
# g    19
# dtype: int64

# %%
list1 = [[1, 'Python'], [2, 'is'], [3, 'Fun.']]

print(pd.DataFrame(list1, columns=['Ids', 'Data']))
# Out:
#    Ids    Data
# 0    1  Python
# 1    2      is
# 2    3    Fun.

# %%
data = {'Name':['Tom', 'nick', 'krish', 'jack'], 'Age':[20, 21, 19, 18]}

print(pd.DataFrame(data))
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
date_string = '2024-12-31'
datetime = pd.to_datetime(date_string)
print(datetime)
# Out:
# 2024-12-31 00:00:00

# %%
from datetime import datetime

date_string = '2024-12-31'
date_ = datetime.strptime(date_string, '%Y-%m-%d')
print(date_)
# Out:
# 2024-12-31 00:00:00

# %%
df1 = pd.DataFrame({'A': [1, 2, 3],'B': [4, 5, 6]}, index=[10, 20, 30])

df2 = pd.DataFrame({'C': [7, 8, 9],'D': [10, 11, 12]}, index=[20, 30, 40])

# Merge both dataframe
result = pd.merge(df1, df2, left_index=True, right_index=True)
print(result)
# Out:
#     A  B  C   D
# 20  2  5  7  10
# 30  3  6  8  11

# %% [markdown]
# How can you perform basic filtering with Pandas?

# %%
filtered_df = df[ (df['Age']>35) and (df['Gender']=='M') ]

# %%
def grades_colors(students_df):
    students_df = students_df[(students_df['grade'] > 90) &
          students_df['favorite_color'].isin(['red','green'])]
    return students_df

# %% [markdown]
# Use Case-1

# %%
addresses = {"address": ["4860 Sunset Boulevard, San Francisco, 94105", "3055 Paradise Lane, Salt Lake City, 84103", "682 Main Street, Detroit, 48204", "9001 Cascade Road, Kansas City, 64102", "5853 Leon Street, Tampa, 33605"]}

cities = {"city": ["Salt Lake City", "Kansas City", "Detroit", "Tampa", "San Francisco"], "state": ["Utah", "Missouri", "Michigan", "Florida", "California"]}

df_addresses = pd.DataFrame(addresses)
df_cities = pd.DataFrame(cities)

# %%
df_addresses
# Out:
#                                        address
# 0  4860 Sunset Boulevard, San Francisco, 94105
# 1    3055 Paradise Lane, Salt Lake City, 84103
# 2              682 Main Street, Detroit, 48204
# 3        9001 Cascade Road, Kansas City, 64102
# 4               5853 Leon Street, Tampa, 33605

# %%
df_cities
# Out:
#              city       state
# 0  Salt Lake City        Utah
# 1     Kansas City    Missouri
# 2         Detroit    Michigan
# 3           Tampa     Florida
# 4   San Francisco  California

# %%
def complete_address(df_addresses, df_cities):
    df_addresses[['street', 'city', 'zipcode']] = df_addresses['address'].str.split(', ', expand=True)
    df_addresses = df_addresses.drop(['address'], axis=1)
    df_addresses = df_addresses.merge(df_cities, on="city")
    df_addresses['address'] = df_addresses[['street', 'city', 'state', 'zipcode']].agg(', '.join, axis=1)
    df_addresses = df_addresses.drop(['street', 'city', 'state', 'zipcode'], axis=1)
    return df_addresses

# %%
result_df= complete_address(df_addresses, df_cities)

# %%
result_df
# Out:
#                                              address
# 0  4860 Sunset Boulevard, San Francisco, Californ...
# 1    3055 Paradise Lane, Salt Lake City, Utah, 84103
# 2          682 Main Street, Detroit, Michigan, 48204
# 3    9001 Cascade Road, Kansas City, Missouri, 64102
# 4            5853 Leon Street, Tampa, Florida, 33605

# %% [markdown]
# Use Case-2

# %%
data = {
    'Name': ['John Doe', 'Jane Doe', 'Mike Roe', 'Sarah Poe'],
    'Age': [32, 28, 45, 37],
    'Height': [170.2, 165.1, 175.3, 160.6],
    'Weight': [70.1, 60.5, 85.6, 58.2],
    'Salary': [56000, 62000, 75000, 69000]
}

df = pd.DataFrame(data)

# %%
df.select_dtypes(include=['int', 'float'])
# Out:
#    Age  Height  Weight  Salary
# 0   32   170.2    70.1   56000
# 1   28   165.1    60.5   62000
# 2   45   175.3    85.6   75000
# 3   37   160.6    58.2   69000

# %%
df.select_dtypes(exclude=['object'])
# Out:
#    Age  Height  Weight  Salary
# 0   32   170.2    70.1   56000
# 1   28   165.1    60.5   62000
# 2   45   175.3    85.6   75000
# 3   37   160.6    58.2   69000

# %% [markdown]
# Use Case-3

# %%
data = {
    'Name': ['John', 'Matt', 'John', 'Cateline'],
    'math_Marks': [18, 20, 19, 15],
    'science_Marks': [10, 20, 15, 12]
}

df = pd.DataFrame(data)
df['total'] = df.apply(lambda row : row["math_Marks"] + row["science_Marks"], axis=1)

df
# Out:
#        Name  math_Marks  science_Marks  total
# 0      John          18             10     28
# 1      Matt          20             20     40
# 2      John          19             15     34
# 3  Cateline          15             12     27

# %%
data = {'units': [1, 2, 3, 4, 5],
        'price': [7, 12, 8, 13, 16]}
# Create a DataFrame df
df = pd.DataFrame(data)

df.plot(x='units', y='price')
# Out:
# <Axes: xlabel='units'>

# %% [markdown]
# How to get the items of series A not present in series B?

# %%
p1 = pd.Series([2, 4, 6, 8, 10])     # here, we are taking the input for p1
p2 = pd.Series([8, 10, 12, 14, 16])      # here, we are taking the input for p2
p1[~p1.isin(p2)]
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %% [markdown]
# How to get the items not common to both series A and series B?

# %%
p1 = pd.Series([2, 4, 6, 8, 10])        # here, we are taking the input values for p1
p2 = pd.Series([8, 10, 12, 14, 16])      # here, we are taking the input values for p2
p1[~p1.isin(p2)]
p_u = pd.Series(np.union1d(p1, p2))  # here, we are performing the union operation
p_i = pd.Series(np.intersect1d(p1, p2))  # here, we are performing the intersect
p_u[~p_u.isin(p_i)]
# Out:
# 0     2
# 1     4
# 2     6
# 5    12
# 6    14
# 7    16
# dtype: int64

# %% [markdown]
# How to get the minimum, 25th percentile, median, 75th, and max of a numeric series?

# %%
p = pd.Series(np.random.normal(14, 6, 22))
state = np.random.RandomState(120)
p = pd.Series(state.normal(14, 6, 22))
np.percentile(p, q=[0, 25, 50, 75, 100])
# Out:
# array([ 4.61498692, 12.15572753, 14.67780756, 17.58054104, 33.24975515])

# %%
data = pd.Series([1, 2, 3, 4, 5])
std_deviation = data.std()
print(round(std_deviation,2))
# Out:
# 1.58

# %% [markdown]
# One Hot Encoding

# %%
data = {
    'City': ['New York', 'Los Angeles', 'New York', 'San Francisco', 'Los Angeles', 'San Francisco']}

# Create a DataFrame
df = pd.DataFrame(data)

# Display original DataFrame
print("Original DataFrame:")
print(df)

# Apply one-hot encoding
df_encoded = pd.get_dummies(df, columns=['City'])

# Display the one-hot encoded DataFrame
print("\nOne-Hot Encoded DataFrame:")
print(df_encoded)
# Out:
# Original DataFrame:
#             City
# 0       New York
# 1    Los Angeles
# 2       New York
# 3  San Francisco
# 4    Los Angeles
# 5  San Francisco
#
# One-Hot Encoded DataFrame:
#    City_Los Angeles  City_New York  City_San Francisco
# 0             False           True               False
# 1              True          False               False
# 2             False           True               False
# 3             False          False                True
# 4              True          False               False
# 5             False          False                True

# %%
df = pd.DataFrame({"Value_1":[None, 14, 35, None, 1,12, 74, 65, None, 1],
                   "Value_2":[None, 24, 54, 3, None,None, 2, 54, 3, None],
                   "Value_3":[20, 16, None, 3, 8,None, 2, 54, 3, None],
                   "Value_4":[None, 2, 54, 3, None,14, 3, None, None, 6]})

df
# Out:
#    Value_1  Value_2  Value_3  Value_4
# 0      NaN      NaN     20.0      NaN
# 1     14.0     24.0     16.0      2.0
# 2     35.0     54.0      NaN     54.0
# 3      NaN      3.0      3.0      3.0
# 4      1.0      NaN      8.0      NaN
# 5     12.0      NaN      NaN     14.0
# 6     74.0      2.0      2.0      3.0
# 7     65.0     54.0     54.0      NaN
# 8      NaN      3.0      3.0      NaN
# 9      1.0      NaN      NaN      6.0

# %%
#Fill the missing value with average values in column Value1.
df['Value_1'].fillna(int(df['Value_1'].mean()), inplace = True)
df
# Out:
# <ipython-input-60-f1674c01370f>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Value_1'].fillna(int(df['Value_1'].mean()), inplace = True)
#    Value_1  Value_2  Value_3  Value_4
# 0     28.0      NaN     20.0      NaN
# 1     14.0     24.0     16.0      2.0
# 2     35.0     54.0      NaN     54.0
# 3     28.0      3.0      3.0      3.0
# 4      1.0      NaN      8.0      NaN
# 5     12.0      NaN      NaN     14.0
# 6     74.0      2.0      2.0      3.0
# 7     65.0     54.0     54.0      NaN
# 8     28.0      3.0      3.0      NaN
# 9      1.0      NaN      NaN      6.0

# %%
df = pd.Series([1, np.nan, np.nan, 3])
print(df.interpolate())
# Out:
# 0    1.000000
# 1    1.666667
# 2    2.333333
# 3    3.000000
# dtype: float64

# %%
s = pd.Series(data = [1,2,3,4,3,5,3,7,1])
print(s.value_counts())
# Out:
# 3    3
# 1    2
# 2    1
# 4    1
# 5    1
# 7    1
# Name: count, dtype: int64

# %%
student_dict = {'Name': ['Kate', 'Harry', 'Sheila'], 'Age': [10, 14, 12], 'Marks': [85, 77, 91]}

df = pd.DataFrame(student_dict)

df1 = df[df['Age'] > 10]
df1
# Out:
#      Name  Age  Marks
# 1   Harry   14     77
# 2  Sheila   12     91

# %%
print (pd.Timedelta('20 days 12 hours 45 minutes 3 seconds'))
# Out:
# 20 days 12:45:03

# %%
student_dict = {'Name': ['Kate', 'Harry', 'Sheila'], 'Age': [10, 11, 12], 'Marks': [85, 77, 91]}

# create DataFrame from dict
student_df = pd.DataFrame(student_dict)
print(student_df)

# set index using column
student_df = student_df.set_index('Name')
print(student_df)
# Out:
#      Name  Age  Marks
# 0    Kate   10     85
# 1   Harry   11     77
# 2  Sheila   12     91
#         Age  Marks
# Name
# Kate     10     85
# Harry    11     77
# Sheila   12     91

# %%
index = pd.Index(['x1', 'x2', 'x3'])
student_df = student_df.set_index(index)
print(student_df)
# Out:
#     Age  Marks
# x1   10     85
# x2   11     77
# x3   12     91

# %%
data = {
  "sales": [23, 34, 56],
  "age": [50, 40, 30]
}

df = pd.DataFrame(data)

print(df.idxmax())
print('********')
print(df.idxmin())
# Out:
# sales    2
# age      0
# dtype: int64
# ********
# sales    0
# age      2
# dtype: int64

# %% [markdown]
# Use Case-4

# %%
import pandas as pd

# Create a DataFrame from a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 40],
    'Department': ['HR', 'Finance', 'IT', 'Marketing']
}
df = pd.DataFrame(data)

# Explore the data
print(df)
print('*******')
print(df.describe())  # Numerical summary
print('*******')

# Filter and sort the data
filtered_df = df[df['Department'].isin(['HR', 'IT'])]
sorted_df = df.sort_values(by='Age', ascending=False)

# Handle missing data
df.at[2, 'Age'] = None  # Simulate missing age for 'Charlie'
df.dropna(inplace=True)  # Drop rows with any missing data

# Group, aggregate, and visualize
grouped_df = df.groupby('Department')['Age'].mean()
grouped_df.plot(kind='bar')

# Export the processed data
df.to_csv('processed_data.csv', index=False)
# Out:
#       Name  Age Department
# 0    Alice   25         HR
# 1      Bob   30    Finance
# 2  Charlie   35         IT
# 3    Diana   40  Marketing
# *******
#              Age
# count   4.000000
# mean   32.500000
# std     6.454972
# min    25.000000
# 25%    28.750000
# 50%    32.500000
# 75%    36.250000
# max    40.000000
# *******

# %%
# Creating DataFrames with different types of indexes
import pandas as pd

# Implicit index
df_implicit = pd.DataFrame({'A': ['a', 'b', 'c'], 'B': [1, 2, 3]})

# Explicit index
df_explicit = pd.DataFrame({'A': ['a', 'b', 'c'], 'B': [1, 2, 3]}, index=['X', 'Y', 'Z'])

# Unique index
df_unique = pd.DataFrame({'A': ['a', 'b', 'c'], 'B': [1, 2, 3]}, index=['1st', '2nd', '3rd'])

# Non-unique index
df_non_unique = pd.DataFrame({'A': ['a', 'b', 'c', 'd'], 'B': [1, 2, 3, 4]}, index=['E', 'E', 'F', 'G'])

# Hierarchical index
df_hierarchical = df_explicit.set_index('A')

print(df_implicit, df_explicit, df_unique, df_non_unique, df_hierarchical, sep='\n\n')
# Out:
#    A  B
# 0  a  1
# 1  b  2
# 2  c  3
#
#    A  B
# X  a  1
# Y  b  2
# Z  c  3
#
#      A  B
# 1st  a  1
# 2nd  b  2
# 3rd  c  3
#
#    A  B
# E  a  1
# E  b  2
# F  c  3
# G  d  4
#
#    B
# A
# a  1
# b  2
# c  3

# %%
# Setting up a DataFrame for operation examples
import pandas as pd

data = {
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
}

df = pd.DataFrame(data, index=['a', 'b', 'c', 'd', 'e'])

# Reindexing
new_index = ['a', 'e', 'c', 'b', 'd']  # Reordering index labels
df_reindexed = df.reindex(new_index)

# Set operations
index1 = pd.Index(['a', 'b', 'c', 'f'])
index2 = pd.Index(['b', 'd', 'c'])
print(index1.intersection(index2))  # Intersection
print(index1.difference(index2))  # Difference

# Data alignment
data2 = {'A': [6, 7], 'B': [60, 70], 'C': [600, 700]}
df2 = pd.DataFrame(data2, index=['a', 'c'])
print(df + df2)  # Aligned based on index labels
# Out:
# Index(['b', 'c'], dtype='object')
# Index(['a', 'f'], dtype='object')
#       A      B       C
# a   7.0   70.0   700.0
# b   NaN    NaN     NaN
# c  10.0  100.0  1000.0
# d   NaN    NaN     NaN
# e   NaN    NaN     NaN

# %%
# slicing vs filtering

# Create a simple DataFrame
data = {'A': [1, 2, 3, 4, 5],
        'B': [10, 20, 30, 40, 50],
        'C': ['foo', 'bar', 'baz', 'qux', 'quux']}
df = pd.DataFrame(data)

# Slicing
sliced_df = df.iloc[1:4, 0:2]
print("Sliced DataFrame:")
print(sliced_df)
# 'iloc' is a positional selection method.

# Filtering
filtered_df = df[df['A'] > 2]
print("\nFiltered DataFrame:")
print(filtered_df)
# Here, we use a conditional expression within the brackets to filter rows.
# Out:
# Sliced DataFrame:
#    A   B
# 1  2  20
# 2  3  30
# 3  4  40
#
# Filtered DataFrame:
#    A   B     C
# 2  3  30   baz
# 3  4  40   qux
# 4  5  50  quux

# %%
# Sample DataFrame
data = {'names': ['Alice', 'Bob', 'Charlie'], 'scores': [80, 90, 85]}
df = pd.DataFrame(data)

# Doubling the scores using .apply() and a lambda function
df['scores'] = df['scores'].apply(lambda x: x*2)

# Verify the changes
df
# Out:
#      names  scores
# 0    Alice     160
# 1      Bob     180
# 2  Charlie     170

# %% [markdown]
# Demonstrate how to handle duplicate rows in a DataFrame.

# %%
# Create a sample DataFrame
data = {'A': [1, 1, 2, 2, 3, 3], 'B': ['a', 'a', 'b', 'b', 'c', 'c']}
df = pd.DataFrame(data)

# Identify duplicate rows
print(df.duplicated())
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
# Drop duplicates
unique_df = df.drop_duplicates()

# Alternatively, you can keep the last occurrence
last_occurrence_df = df.drop_duplicates(keep='last')

# To drop in place, use the `inplace` parameter
df.drop_duplicates(inplace=True)

df
# Out:
#    A  B
# 0  1  a
# 2  2  b
# 4  3  c

# %%
# Aggregate using mean
mean_df = df.groupby('A').mean(numeric_only=True)
print('mean-',mean_df)

# Count duplicates
num_duplicates = df.duplicated().sum()
print('Count duplicates',num_duplicates)

# Keep the last occurrence
df_last = df.drop_duplicates(keep='last')
print('last occurrence',df_last)

# Consider only the 'A' column to identify duplicates
df_unique_A = df.drop_duplicates(subset=['A'])
print(df_unique_A)
# Out:
# mean- Empty DataFrame
# Columns: []
# Index: [1, 2, 3]
# Count duplicates 0
# last occurrence    A  B
# 0  1  a
# 2  2  b
# 4  3  c
#    A  B
# 0  1  a
# 2  2  b
# 4  3  c

# %% [markdown]
# Describe how you would convert categorical data into numeric format.

# %% [markdown]
# 1. Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

data = {'Size': ['S', 'M', 'L', 'XL', 'M']}
df = pd.DataFrame(data)

le = LabelEncoder()
df['Size_LabelEncoded'] = le.fit_transform(df['Size'])
df
# Out:
#   Size  Size_LabelEncoded
# 0    S                  2
# 1    M                  1
# 2    L                  0
# 3   XL                  3
# 4    M                  1

# %% [markdown]
# 2. One-Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder

# Avoids SettingWithCopyWarning
df = pd.get_dummies(df, prefix=['Size'], columns=['Size'])

df
# Out:
#    Size_LabelEncoded  Size_L  Size_M  Size_S  Size_XL
# 0                  2   False   False    True    False
# 1                  1   False    True   False    False
# 2                  0    True   False   False    False
# 3                  3   False   False   False     True
# 4                  1   False    True   False    False

# %% [markdown]
# How can you pivot data in a DataFrame?

# %% [markdown]
# 1. Pivoting with pivot

# %%
data = {
    'Date': ['2020-01-01', '2020-01-01', '2020-01-02', '2020-01-02'],
    'Category': ['A', 'B', 'A', 'B'],
    'Value': [10, 20, 30, 40]
}

df = pd.DataFrame(data)

# Pivot the DataFrame
pivot_df = df.pivot(index='Date', columns='Category', values='Value')
print(pivot_df)
# Out:
# Category     A   B
# Date
# 2020-01-01  10  20
# 2020-01-02  30  40

# %% [markdown]
# 2. Pivoting with pivot_table

# %%
data = {
    'Date': ['2020-01-01', '2020-01-01', '2020-01-02', '2020-01-02'],
    'Category': ['A', 'B', 'A', 'B'],
    'Value': [10, 20, 30, 40]
}

df = pd.DataFrame(data)

# Pivoting the DataFrame using pivot_table
pivot_table_df = df.pivot_table(index='Date', columns='Category', values='Value', aggfunc='sum')
print(pivot_table_df)
# Out:
# Category     A   B
# Date
# 2020-01-01  10  20
# 2020-01-02  30  40

# %%
data = {'A': [1, 2, 3, 4, 5], 'B': [10, 20, 30, 40, 50]}
df = pd.DataFrame(data)

# Applying 'where'
result = df.where(df > 2, df * 10)

print(result)
# Out:
#     A   B
# 0  10  10
# 1  20  20
# 2   3  30
# 3   4  40
# 4   5  50

# %%
data = {'A': [1, 2, 3], 'B': [4, 5, 6]}
df = pd.DataFrame(data)

# Define the function to calculate the difference
def diff_calc(row):
    return row['B'] - row['A']

# Apply the custom function along the columns
df['Diff'] = df.apply(diff_calc, axis='columns')

print(df)
# Out:
#    A  B  Diff
# 0  1  4     3
# 1  2  5     3
# 2  3  6     3
